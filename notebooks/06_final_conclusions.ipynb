# %% [markdown]
# # 06 - Final Conclusions
#
# # Conclusiones finales del proyecto
#
# ## Sistema de análisis y predicción de riesgo operacional logístico
#
# Este notebook presenta las conclusiones finales obtenidas durante el desarrollo completo del proyecto de Machine Learning aplicado a operaciones logísticas.
#
# A lo largo del proyecto se desarrollaron distintas etapas:
#
# - limpieza y transformación de datos;
# - feature engineering;
# - análisis exploratorio;
# - selección de targets;
# - modelos supervisados;
# - optimización de hiperparámetros;
# - aprendizaje no supervisado.
#
# El objetivo principal fue analizar operaciones logísticas y construir modelos capaces de identificar operaciones de alto riesgo operacional.

# %% [markdown]
# # 1. Resumen general del proyecto
#
# El proyecto se desarrolló utilizando información operacional proveniente de:
#
# - envíos;
# - rutas;
# - vehículos;
# - incidencias logísticas.
#
# A partir de estos datos se construyó un dataset integrado orientado a Machine Learning.
#
# Durante el proceso se realizaron:
#
# - limpieza de datos;
# - tratamiento de valores extremos;
# - creación de variables derivadas;
# - transformaciones logarítmicas;
# - construcción de indicadores operacionales.
#
# El dataset final permitió representar correctamente:
#
# - exigencia vehicular;
# - utilización de capacidad;
# - velocidad operacional;
# - sobrecarga;
# - distancia recorrida;
# - riesgo operacional.
#
# Esto permitió construir modelos mucho más robustos y coherentes operacionalmente.

# %% [markdown]
# # 2. Hallazgos principales del análisis exploratorio
#
# El análisis exploratorio permitió identificar patrones relevantes dentro de la operación logística.
#
# ## Principales hallazgos
#
# ### Riesgo operacional asociado a velocidad y distancia
#
# Se observó una relación importante entre:
#
# - velocidad promedio;
# - rutas largas;
# - riesgo operacional.
#
# Las operaciones más rápidas y extensas tendieron a concentrar mayores niveles de riesgo.
#
# ---
#
# ### Sobrecarga y utilización de capacidad
#
# Las variables:
#
# - uso_capacidad_kg;
# - sobrecarga_kg;
# - vehiculo_exigido;
#
# mostraron una fuerte relación con operaciones críticas.
#
# Esto sugiere que operaciones cercanas o superiores a la capacidad vehicular incrementan significativamente el riesgo operacional.
#
# ---
#
# ### Importancia del feature engineering
#
# Las nuevas variables creadas permitieron capturar patrones que no eran visibles en las variables originales.
#
# Especialmente relevantes fueron:
#
# - riesgo_velocidad;
# - uso_capacidad_kg_recalculado;
# - variables logarítmicas;
# - velocidad_alta;
# - ruta_larga.
#
# Estas variables fueron determinantes en prácticamente todos los modelos desarrollados.

# %% [markdown]
# # 3. Targets evaluados
#
# Durante el proyecto se analizaron distintas predicciones candidatas.
#
# ## Targets evaluados
#
# - tiene_incidencia
# - entrega_tardia
# - entrega_tardia_v3
# - incidencia_multiclase
# - riesgo_operacional_alto
# - riesgo_operacional
#
# Cada uno fue analizado mediante:
#
# - métricas;
# - separación de clases;
# - coherencia operacional;
# - interpretabilidad;
# - estabilidad de modelos.
#
# ---
#
# ## Targets seleccionados
#
# Finalmente se seleccionaron:
#
# ### Clasificación
# `riesgo_operacional_alto`
#
# ### Regresión
# `riesgo_operacional`
#
# Estos objetivos fueron los que presentaron:
#
# - mejores métricas;
# - mayor coherencia operacional;
# - patrones más claros;
# - mayor utilidad estratégica.

# %% [markdown]
# # 4. Resultados de modelos supervisados
#
# ## Clasificación
#
# Se probaron distintos modelos:
#
# - Logistic Regression
# - Decision Tree
# - Random Forest
# - KNN
# - SVM
# - Gaussian Naive Bayes
#
# El mejor desempeño fue obtenido por:
#
# # Random Forest Classifier
#
# ## Resultados principales
#
# | Métrica | Resultado |
# |---|---|
# | Accuracy | 0.985 |
# | Balanced Accuracy | 0.983 |
# | F1-score | 0.9697 |
# | AUC ROC | ~0.998 |
#
# Estos resultados demuestran una capacidad extremadamente alta para identificar operaciones de alto riesgo.
#
# ---
#
# ## Regresión
#
# Se evaluaron:
#
# - Linear Regression
# - Decision Tree Regressor
# - Random Forest Regressor
# - KNN Regressor
# - SVR
#
# El mejor modelo fue:
#
# # Random Forest Regressor
#
# ## Resultados principales
#
# | Métrica | Resultado |
# |---|---|
# | MAE | ~49 |
# | RMSE | ~110 |
# | R² | ~0.996 |
#
# El modelo logró estimar el riesgo operacional con un nivel de error muy bajo.

# %% [markdown]
# # 5. Optimización de hiperparámetros
#
# Se aplicaron técnicas de:
#
# - GridSearchCV;
# - validación cruzada;
# - Optuna.
#
# El objetivo fue encontrar configuraciones más robustas y generalizables.
#
# ---
#
# ## Configuración final - Clasificación
#
# ```python
# RandomForestClassifier(
#     n_estimators=258,
#     max_depth=13,
#     min_samples_split=4,
#     min_samples_leaf=2,
#     random_state=42
# )
# ```
#
# ---
#
# ## Configuración final - Regresión
#
# ```python
# RandomForestRegressor(
#     n_estimators=273,
#     max_depth=14,
#     min_samples_split=6,
#     min_samples_leaf=1,
#     random_state=42
# )
# ```
#
# La optimización confirmó que los modelos ya poseían un desempeño muy sólido desde las primeras etapas del proyecto.
#
# Optuna permitió realizar ajustes finos y mejorar estabilidad y generalización.

# %% [markdown]
# # 6. Variables más importantes
#
# Los modelos y análisis realizados mostraron consistencia respecto a las variables más influyentes.
#
# ## Variables más relevantes
#
# - uso_capacidad_kg_recalculado
# - sobrecarga_kg
# - vehiculo_exigido
# - distancia_km
# - riesgo_velocidad
# - velocidad_promedio_km_h
# - velocidad_alta
# - ruta_larga
#
# Estas variables dominaron:
#
# - modelos supervisados;
# - PCA;
# - clustering;
# - análisis de correlación.
#
# Esto valida fuertemente la lógica operacional del proyecto.

# %% [markdown]
# # 7. Aprendizaje no supervisado
#
# El análisis de clustering permitió identificar grupos naturales dentro de las operaciones logísticas.
#
# Se utilizaron:
#
# - PCA;
# - KMeans;
# - método del codo;
# - silhouette score.
#
# ---
#
# ## Hallazgos principales
#
# Se identificaron clusters asociados a:
#
# - operaciones normales;
# - rutas rápidas;
# - operaciones pesadas;
# - operaciones críticas de alto riesgo.
#
# Uno de los resultados más importantes fue que el clustering logró separar naturalmente operaciones de alto riesgo sin utilizar variables objetivo supervisadas.
#
# Esto valida:
#
# - la calidad del dataset;
# - el feature engineering;
# - la coherencia de las variables creadas.

# %% [markdown]
# # 8. Impacto operacional del proyecto
#
# Los modelos desarrollados podrían utilizarse en escenarios reales para:
#
# - detectar operaciones críticas antes de que ocurran incidentes;
# - priorizar monitoreo de envíos;
# - identificar vehículos altamente exigidos;
# - optimizar planificación logística;
# - reducir riesgos operacionales;
# - mejorar toma de decisiones.
#
# Además, los resultados muestran que el riesgo operacional no depende de una única variable, sino de combinaciones complejas entre:
#
# - velocidad;
# - distancia;
# - carga;
# - utilización de capacidad;
# - exigencia vehicular.

# %% [markdown]
# # 9. Limitaciones del proyecto
#
# Aunque los resultados obtenidos fueron muy positivos, existen algunas limitaciones importantes.
#
# ## Limitaciones identificadas
#
# - El dataset fue generado para fines académicos y no corresponde a una operación logística real completa.
# - Algunas variables poseen relaciones altamente estructuradas, lo que puede facilitar ciertos modelos.
# - Existen variables derivadas creadas a partir de lógica operacional definida manualmente.
# - No se dispone de información temporal avanzada ni eventos en tiempo real.
#
# A pesar de esto, el proyecto logra representar adecuadamente una problemática logística compleja.

# %% [markdown]
# # 10. Trabajo futuro
#
# El proyecto podría ampliarse mediante:
#
# - integración de datos GPS reales;
# - monitoreo en tiempo real;
# - series temporales;
# - redes neuronales;
# - detección automática de anomalías;
# - sistemas de alerta temprana;
# - dashboards operacionales.
#
# También sería posible desplegar los modelos en aplicaciones reales para monitoreo logístico continuo.

# %% [markdown]
# # 11. Conclusión general
#
# El proyecto logró desarrollar exitosamente un sistema de análisis y predicción de riesgo operacional logístico utilizando técnicas modernas de Machine Learning.
#
# Los resultados obtenidos demostraron que:
#
# - el dataset contiene patrones operacionales relevantes;
# - las variables creadas mediante feature engineering fueron altamente efectivas;
# - Random Forest fue el modelo más robusto para clasificación y regresión;
# - el clustering permitió identificar perfiles operacionales naturales.
#
# Además, se comprobó que variables relacionadas con:
#
# - velocidad;
# - distancia;
# - sobrecarga;
# - utilización de capacidad;
# - exigencia vehicular;
#
# son factores fundamentales dentro del riesgo operacional.
#
# Finalmente, el proyecto permitió integrar:
#
# - análisis exploratorio;
# - aprendizaje supervisado;
# - optimización;
# - aprendizaje no supervisado;
#
# en una solución completa y coherente orientada al análisis logístico.
