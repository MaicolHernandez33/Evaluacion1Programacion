# %%
# %load_ext kedro.ipython
# Out:
# [04/06/26 20:55:34] INFO     Using                                                                  ]8;id=662819;file://C:\Users\maico\Evaluacion1\.venv\lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=62705;file://C:\Users\maico\Evaluacion1\.venv\lib\site-packages\kedro\framework\project\__init__.py#275\275]8;;\
#                              'C:\Users\maico\Evaluacion1\.venv\lib\site-packages\kedro\framework\pr
#                              oject\rich_logging.yml' as logging configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=637620;file://C:\Users\maico\Evaluacion1\.venv\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=836954;file://C:\Users\maico\Evaluacion1\.venv\lib\site-packages\kedro\ipython\__init__.py#64\64]8;;\
# ...

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\maico\Evaluacion1\.venv\Scripts\python.exe

# %%
import pandas as pd
import kedro_datasets

# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\maico\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip
