# %% [markdown]
# # 07 - Project Summary for Presentation
#
# # Resumen ejecutivo del proyecto para presentación final
#
# ## Sistema de análisis y predicción de riesgo operacional logístico
#
# Este notebook resume las partes más importantes del proyecto para ser utilizadas durante la presentación final y el video explicativo.
#
# El objetivo es condensar:
#
# - contexto del problema;
# - metodología;
# - análisis exploratorio;
# - feature engineering;
# - modelos supervisados;
# - optimización;
# - clustering;
# - conclusiones principales.
#
# La idea es contar la historia completa del proyecto de forma clara, profesional y coherente.

# %% [markdown]
# # 1. Introducción al problema
#
# El proyecto se enfocó en el análisis de operaciones logísticas utilizando técnicas de Machine Learning.
#
# Se trabajó con información relacionada a:
#
# - envíos;
# - rutas;
# - vehículos;
# - incidencias logísticas.
#
# El objetivo principal fue identificar operaciones críticas y construir modelos capaces de:
#
# - detectar operaciones de alto riesgo;
# - estimar el nivel de riesgo operacional;
# - segmentar perfiles logísticos.
#
# ---
#
# ## Pregunta principal del proyecto
#
# > ¿Es posible identificar y predecir operaciones logísticas de alto riesgo utilizando Machine Learning?

# %% [markdown]
# # 2. Construcción del dataset
#
# El proyecto comenzó integrando distintos datasets logísticos:
#
# - `envios.csv`
# - `rutas.csv`
# - `vehiculos.csv`
# - `incidencias.csv`
#
# A partir de esta integración se construyó un dataset consolidado orientado a Machine Learning.
#
# ---
#
# ## Procesos realizados
#
# Durante esta etapa se realizaron:
#
# - limpieza de datos;
# - tratamiento de valores faltantes;
# - manejo de outliers;
# - creación de variables derivadas;
# - transformaciones logarítmicas;
# - construcción de indicadores operacionales.
#
# El resultado final fue:
#
# # `dataset_modelo_v3.csv`

# %% [markdown]
# # 3. Feature Engineering
#
# Una de las partes más importantes del proyecto fue la creación de nuevas variables.
#
# Estas variables permitieron representar mejor el comportamiento operacional de los envíos.
#
# ---
#
# ## Variables creadas más importantes
#
# ### Variables operacionales
#
# - `uso_capacidad_kg_recalculado`
# - `uso_capacidad_m3_recalculado`
# - `densidad_carga`
# - `riesgo_velocidad`
# - `vehiculo_exigido`
# - `sobrecarga_kg`
# - `ruta_larga`
# - `velocidad_alta`
#
# ---
#
# ## Variables logarítmicas
#
# - `peso_kg_log`
# - `distancia_km_log`
# - `velocidad_promedio_km_h_log`
# - `riesgo_velocidad_log`
#
# ---
#
# ## ¿Por qué se utilizaron transformaciones logarítmicas?
#
# Las transformaciones logarítmicas permitieron:
#
# - reducir asimetrías;
# - controlar valores extremos;
# - estabilizar distribuciones;
# - facilitar el aprendizaje de los modelos.
#
# Estas variables terminaron siendo fundamentales en prácticamente todos los modelos desarrollados.

# %% [markdown]
# # 4. Principales hallazgos del EDA
#
# El análisis exploratorio permitió descubrir patrones importantes dentro de la operación logística.
#
# ---
#
# ## Hallazgos principales
#
# ### Velocidad y distancia
#
# Las operaciones:
#
# - más rápidas;
# - más extensas;
# - con rutas largas;
#
# tendieron a presentar mayores niveles de riesgo operacional.
#
# ---
#
# ### Sobrecarga y utilización de capacidad
#
# Las variables relacionadas con:
#
# - sobrecarga;
# - utilización de capacidad;
# - exigencia vehicular;
#
# mostraron una relación directa con operaciones críticas.
#
# ---
#
# ### Riesgo operacional
#
# El riesgo operacional no dependía de una única variable, sino de combinaciones complejas entre:
#
# - velocidad;
# - distancia;
# - carga;
# - capacidad;
# - exigencia vehicular.

# %% [markdown]
# # 5. Targets analizados
#
# Durante el proyecto se probaron distintos objetivos de predicción.
#
# ---
#
# ## Targets evaluados
#
# - `tiene_incidencia`
# - `entrega_tardia`
# - `entrega_tardia_v3`
# - `incidencia_multiclase`
# - `riesgo_operacional_alto`
# - `riesgo_operacional`
#
# ---
#
# ## Targets finales seleccionados
#
# ### Clasificación
# `riesgo_operacional_alto`
#
# ### Regresión
# `riesgo_operacional`
#
# Estos targets fueron seleccionados porque:
#
# - mostraron mejores métricas;
# - poseían mayor coherencia operacional;
# - generaban modelos más estables;
# - entregaban mayor utilidad estratégica.

# %% [markdown]
# # 6. Modelos supervisados
#
# ## Clasificación
#
# Se probaron distintos modelos:
#
# - Logistic Regression
# - Decision Tree
# - Random Forest
# - KNN
# - SVM
# - GaussianNB
#
# ---
#
# ## Mejor modelo
#
# # Random Forest Classifier
#
# ### Resultados obtenidos
#
# | Métrica | Resultado |
# |---|---|
# | Accuracy | 0.985 |
# | Balanced Accuracy | 0.983 |
# | F1-score | 0.9697 |
# | AUC ROC | ~0.998 |
#
# ---
#
# ## Interpretación
#
# El modelo logró identificar operaciones de alto riesgo con una precisión extremadamente alta.
#
# Además, las curvas ROC mostraron excelente separación entre operaciones normales y operaciones críticas.

# %% [markdown]
# # 7. Modelos de regresión
#
# Se evaluaron distintos modelos:
#
# - Linear Regression
# - Decision Tree Regressor
# - Random Forest Regressor
# - KNN Regressor
# - SVR
#
# ---
#
# ## Mejor modelo
#
# # Random Forest Regressor
#
# ### Resultados obtenidos
#
# | Métrica | Resultado |
# |---|---|
# | MAE | ~49 |
# | RMSE | ~110 |
# | R² | ~0.996 |
#
# ---
#
# ## Interpretación
#
# El modelo logró estimar el nivel numérico del riesgo operacional con un error muy bajo.
#
# Esto permite no solo clasificar operaciones críticas, sino también estimar la intensidad del riesgo.

# %% [markdown]
# # 8. Optimización de hiperparámetros
#
# Se aplicaron:
#
# - GridSearchCV;
# - validación cruzada;
# - Optuna.
#
# El objetivo fue encontrar configuraciones más robustas y generalizables.
#
# ---
#
# ## Modelo final clasificación
#
# ```python
# RandomForestClassifier(
#     n_estimators=258,
#     max_depth=13,
#     min_samples_split=4,
#     min_samples_leaf=2,
#     random_state=42
# )
# ```
#
# ---
#
# ## Modelo final regresión
#
# ```python
# RandomForestRegressor(
#     n_estimators=273,
#     max_depth=14,
#     min_samples_split=6,
#     min_samples_leaf=1,
#     random_state=42
# )
# ```
#
# ---
#
# ## Hallazgo importante
#
# Los modelos ya presentaban resultados muy sólidos antes de Optuna.
#
# Optuna permitió realizar ajustes finos y confirmar configuraciones robustas.

# %% [markdown]
# # 9. Variables más importantes
#
# Las variables más relevantes del proyecto fueron:
#
# - uso_capacidad_kg_recalculado
# - sobrecarga_kg
# - vehiculo_exigido
# - distancia_km
# - riesgo_velocidad
# - velocidad_promedio_km_h
# - velocidad_alta
# - ruta_larga
#
# Estas variables dominaron:
#
# - modelos supervisados;
# - PCA;
# - clustering;
# - análisis de correlación.
#
# Esto validó fuertemente la lógica operacional del proyecto.

# %% [markdown]
# # 10. Aprendizaje no supervisado
#
# También se aplicaron técnicas de:
#
# - PCA;
# - KMeans;
# - clustering logístico.
#
# El objetivo fue detectar grupos naturales dentro de las operaciones logísticas.
#
# ---
#
# ## Hallazgos principales
#
# Se identificaron clusters asociados a:
#
# - operaciones normales;
# - operaciones pesadas;
# - rutas rápidas;
# - operaciones críticas de alto riesgo.
#
# ---
#
# ## Resultado importante
#
# El clustering logró detectar operaciones críticas sin utilizar variables objetivo supervisadas.
#
# Esto validó:
#
# - el feature engineering;
# - la calidad del dataset;
# - la coherencia operacional del proyecto.

# %% [markdown]
# # 11. Impacto operacional del proyecto
#
# Los modelos desarrollados podrían utilizarse en escenarios reales para:
#
# - detectar operaciones críticas antes de incidentes;
# - priorizar monitoreo logístico;
# - optimizar planificación;
# - identificar vehículos exigidos;
# - reducir riesgos operacionales;
# - mejorar toma de decisiones.
#
# ---
#
# ## Interpretación estratégica
#
# El proyecto demuestra que el riesgo operacional surge de combinaciones complejas entre:
#
# - velocidad;
# - distancia;
# - carga;
# - utilización de capacidad;
# - exigencia vehicular.
#
# No depende de una única variable aislada.

# %% [markdown]
# # 12. Limitaciones del proyecto
#
# Aunque los resultados fueron muy positivos, existen algunas limitaciones:
#
# - dataset académico;
# - relaciones parcialmente estructuradas;
# - ausencia de datos GPS reales;
# - ausencia de monitoreo en tiempo real;
# - variables derivadas construidas manualmente.
#
# Aun así, el proyecto logró representar una problemática logística compleja de forma consistente.

# %% [markdown]
# # 13. Trabajo futuro
#
# El proyecto podría ampliarse mediante:
#
# - monitoreo en tiempo real;
# - dashboards operacionales;
# - sistemas de alertas;
# - series temporales;
# - redes neuronales;
# - detección automática de anomalías;
# - integración con GPS y sensores reales.

# %% [markdown]
# # 14. Conclusión final del proyecto
#
# El proyecto logró desarrollar exitosamente un sistema completo de análisis y predicción de riesgo operacional logístico utilizando técnicas modernas de Machine Learning.
#
# ---
#
# ## Principales logros
#
# - construcción de dataset integrado;
# - feature engineering avanzado;
# - modelos supervisados robustos;
# - optimización de hiperparámetros;
# - clustering operacional;
# - segmentación logística.
#
# ---
#
# ## Conclusión principal
#
# Se comprobó que variables relacionadas con:
#
# - velocidad;
# - distancia;
# - sobrecarga;
# - utilización de capacidad;
# - exigencia vehicular;
#
# son factores fundamentales dentro del riesgo operacional.
#
# ---
#
# ## Resultado final
#
# Los modelos basados en Random Forest lograron:
#
# - identificar operaciones críticas;
# - estimar riesgo operacional;
# - segmentar operaciones logísticas;
#
# con un desempeño extremadamente alto.
#
# Esto demuestra el potencial del Machine Learning aplicado a logística y gestión operacional.

# %% [markdown]
# # 15. Estructura sugerida para el video (10 minutos)
#
# ## Introducción (1 minuto)
#
# - contexto del problema;
# - objetivo del proyecto;
# - datasets utilizados.
#
# ---
#
# ## Limpieza y feature engineering (2 minutos)
#
# - integración de datasets;
# - variables creadas;
# - transformaciones logarítmicas;
# - importancia del preprocesamiento.
#
# ---
#
# ## EDA y hallazgos (2 minutos)
#
# - velocidad;
# - distancia;
# - sobrecarga;
# - riesgo operacional;
# - gráficos principales.
#
# ---
#
# ## Modelos supervisados (2 minutos)
#
# - clasificación;
# - regresión;
# - mejores métricas;
# - Random Forest.
#
# ---
#
# ## Optimización y clustering (2 minutos)
#
# - GridSearchCV;
# - Optuna;
# - PCA;
# - clusters logísticos.
#
# ---
#
# ## Conclusión final (1 minuto)
#
# - impacto operacional;
# - utilidad del sistema;
# - trabajo futuro.
